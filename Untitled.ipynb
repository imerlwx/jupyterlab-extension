# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('recent-grads.csv')

# %%
df.head(5)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
grouped = df.groupby('Major_category')['Median'].mean()

# %%
plt.figure(figsize=(10,6)) # This line is used to adjust the size of the figure
grouped.sort_values().plot(kind='barh', color='skyblue') # We use kind='barh' for a horizontal bar plot

plt.xlabel('Median Salary') # Labeling the x-axis
plt.ylabel('Major Categories') # Labeling the y-axis
plt.title('Median Salary across Major Categories') # Giving the plot a title

plt.show() # This line is used to display the plot

# %%
df_engineering = df[df['Major_category'] == 'Engineering']

# %%
grouped_engineering = df_engineering.groupby('Major')['Median'].mean()

# %%
plt.figure(figsize=(10,6))
grouped_engineering.sort_values().plot(kind='barh', color='skyblue')

plt.xlabel('Median Salary')
plt.ylabel('Engineering Majors')
plt.title('Median Salary across Engineering Majors')

plt.show()

# %%
df_grouped = df.groupby('Major_category').agg({'ShareWomen': 'mean', 'Median': 'mean'})

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_grouped['ShareWomen'], df_grouped['Median'], alpha=0.5)

# Adding labels for x and y axis
plt.xlabel('Proportion of Women')
plt.ylabel('Median Salary')

# Adding a title
plt.title('Relationship between Proportion of Women and Median Salary')

# Display the plot
plt.show()

# %%
unempoly_grouped = df.groupby('Major_category')['Unemployment_rate'].mean()

# %%
print(unempoly_grouped)
# Out:
# Major_category
# Agriculture & Natural Resources        0.056328
# Arts                                   0.090173
# Biology & Life Science                 0.060918
# Business                               0.071064
# Communications & Journalism            0.075538
# Computers & Mathematics                0.084256
# Education                              0.051702
# Engineering                            0.063334
# Health                                 0.065920
# Humanities & Liberal Arts              0.081008
# Industrial Arts & Consumer Services    0.048071
# Interdisciplinary                      0.070861
# Law & Public Policy                    0.090805
# Physical Sciences                      0.046511
# Psychology & Social Work               0.072065
# Social Science                         0.095729
# Name: Unemployment_rate, dtype: float64

# %%
women_grouped = df.groupby('Major_category')['ShareWomen'].mean()

# %%
print(women_grouped)
# Out:
# Major_category
# Agriculture & Natural Resources        0.405267
# Arts                                   0.603658
# Biology & Life Science                 0.587193
# Business                               0.483198
# Communications & Journalism            0.658384
# Computers & Mathematics                0.311772
# Education                              0.748507
# Engineering                            0.238889
# Health                                 0.795152
# Humanities & Liberal Arts              0.631790
# Industrial Arts & Consumer Services    0.349523
# Interdisciplinary                      0.770901
# Law & Public Policy                    0.483649
# Physical Sciences                      0.508683
# Psychology & Social Work               0.794397
# Social Science                         0.553962
# Name: ShareWomen, dtype: float64

# %%
df_grouped = df.groupby('Major_category').agg({'ShareWomen': 'mean', 'Unemployment_rate': 'mean'})

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_grouped['ShareWomen'], df_grouped['Unemployment_rate'], alpha=0.5)

# Adding labels for x and y axis
plt.xlabel('Proportion of Women')
plt.ylabel('Unemployment rate')

# Adding a title
plt.title('Relationship between Proportion of Women and Median Salary')

# Display the plot
plt.show()
